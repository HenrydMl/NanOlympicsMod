# %% [markdown]
# # Setup:

# %% [markdown]
# This requires a reference .fa file and a .gtf file (here we are using the ones from Maestri, human genome)
# IF the bash commands fail from the notebook, just use the terminal

# %% [markdown]
# ## 1. Setting up the files for chromosome 1

# %%
# %%bash
# startloc="/globalscratch/ulb/mlg/hdmarmol/nanolympics/startingfiles/references"
# endloc="/globalscratch/ulb/mlg/hdmarmol/nanolympics/startingfiles/chr1"

# %%
# This checks for allthe lines whose first column is only equal tothe chromosome number we want (here 1)
# %%bash
awk '$1 == "1"' "${startloc}/Homo_sapiens.GRCh38.109.gtf" > "${endloc}/chr1.gtf"

# %%
# create a .fai file from the .fa file for the region of interest. If it doesn't work do it from terminal

# %%bash
# Load the right release 
module load releases/2022b
module load SAMtools/1.17-GCC-12.2.0

samtools faidx "${startloc}/hg38.fa" chr1 > "${endloc}/chr1.fa"

# %%
# Convert the GTF to BED format: This makes an EXON bed. They have the gene id

# %%bash
awk '$3 == "exon" { match($9, /gene_id "[^"]+"/); gene_id = $10; print $1 "\t" $4 "\t" $5 "\t" gene_id "\t.\t" $7}' "${endloc}/chr1.gtf" > "${endloc}/chr1_exons.bed"

# IF there is a mismatch in the chromosome naming between the files:
awk 'BEGIN {OFS="\t"} {if ($1 == "1") $1 = "chr1"; print}' "${endloc}/chr1_exons.bed" > "${endloc}/chr1_exons_fixed.bed"

# %%
# Converts the GTF to BED format: This makes a transcriptome bed, with transcript id
# %%bash
awk '$3 == "transcript" {transcript_id = $14; gsub(/;$/, "", transcript_id); \
    gsub(/"/, "", transcript_id); print $1 "\t" $4 "\t" $5 "\t" transcript_id "\t.\t" $7;}' \
    "${endloc}/chr1.gtf" > "${endloc}/chr1_transcriptome.bed"
awk 'BEGIN {OFS="\t"} {if ($1 == "1") $1 = "chr1"; print}' "${endloc}/chr1_transcriptome.bed" > "${endloc}/chr1_transcriptome_fixed.bed"

# Converts the GTF to BED format: This makes a Gene bed

awk '$3 == "gene" {gene_id = $10; gsub(/;$/, "", gene_id); gsub(/"/, "", gene_id); print $1 "\t" $4 "\t" $5 "\t" gene_id "\t.\t" $7;}' "${endloc}/chr1.gtf" > "${endloc}/chr1_genes.bed"
awk 'BEGIN {OFS="\t"} {if ($1 == "1") $1 = "chr1"; print}' "${endloc}/chr1_genes.bed" > "${endloc}/chr1_genes_fixed.bed"

# %%
# Make a transcriptome FASTA
# %%bash
module load releases/2023a
module load BEDTools/2.31.0-GCC-12.3.0

bedtools getfasta -fi "${endloc}/chr1.fa" -bed "${endloc}/chr1_transcriptome_fixed.bed" -name -split > "${endloc}/chr1_transcriptome.fa"

# %%
# Make the FAI for the transcriptome FASTA

# %%bash
# Load the right release 
module load releases/2022b
module load SAMtools/1.17-GCC-12.2.0

samtools faidx "${endloc}/chr1_transcriptome.fa" > "${endloc}/chr1_transcriptome_other.fa"

# %% [markdown]
# ## 2: Making the genestoranscript file

# %%
# Variables

gtfFile = "/globalscratch/ulb/mlg/hdmarmol/nanolympics/startingfiles/chr1/chr1.gtf"
genesToTanscript = "/globalscratch/ulb/mlg/hdmarmol/nanolympics/startingfiles/chr1/chr1_genesToTranscript.txt"
separator = "\t"

# %%
# making a dictionary of genes: [transcripts]
# Ideally I should make a condition to just find the column that has gene_name and take the one next to it, or even better split 
# by ";" and check for the one that startswith what I want

geneDict = {}
biotypes = []

try:
    with open(gtfFile, "r") as f:
            for line in f:
                #line = f.readline()
                line_ls = line.split("\t")
                #print (line_ls[0:8])
                info = line_ls[8].split(" ")
                #print(info)
                
                # Check if new gene
                if line_ls[2] == "transcript":
                    gene_name = info[9]
                    gene_name = gene_name[1:len(gene_name)-2]
                    transcript_id = info[5][1:len(info[5])-2]
                    #print(gene_name, transcript_id)
                    if info[8] != "gene_name":
                    #print(line)
                        #print(info)
                        if info[11] not in biotypes:
                            biotypes.append(info[11])
                        continue
                    if gene_name not in geneDict.keys():
                        geneDict[gene_name] = []
                    if transcript_id not in geneDict[gene_name]:
                        geneDict[gene_name].append(transcript_id)
            print(geneDict)
            print(geneDict.keys())
            print(len(geneDict.keys()))
            print(biotypes)
    
    with open(genesToTanscript, "w") as f:
        for (k,v) in geneDict.items():
            line = k
            for transcript in v:
                line += f"\t{transcript}"
            line += "\n"
            f.write(line)
            
except:
    print(".gtf File not found in path")
# Out:
# {'ATAD3B': ['ENST00000673477', 'ENST00000472194', 'ENST00000378736', 'ENST00000485748', 'ENST00000474481', 'ENST00000308647'], 'DDX11L17': ['ENST00000624431'], 'PRDM16': ['ENST00000511072', 'ENST00000607632', 'ENST00000378391', 'ENST00000514189', 'ENST00000270722', 'ENST00000512462', 'ENST00000463591', 'ENST00000509860', 'ENST00000378389', 'ENST00000606170'], 'PEX10': ['ENST00000288774', 'ENST00000447513', 'ENST00000650293', 'ENST00000507596', 'ENST00000510434', 'ENST00000508384', 'ENST00000515760', 'ENST00000502666', 'ENST00000514502'], 'LINC01345': ['ENST00000635247', 'ENST00000635127', 'ENST00000425194', 'ENST00000671015'], 'EEF1DP6': ['ENST00000449232'], 'PEX14': ['ENST00000472851', 'ENST00000356607', 'ENST00000491661', 'ENST00000492696'], 'LINC01646': ['ENST00000634256', 'ENST00000635556', 'ENST00000420522', 'ENST00000659059', 'ENST00000667354', 'ENST00000659083', 'ENST00000661628', 'ENST00000666685'], 'LINC01777': ['ENST00000635002', 'ENST00000423197', 'ENST00000635312', 'ENST00000669931', 'ENST00000635642', 'ENST00000663417', 'ENST00000671656', 'ENST00000667352', 'ENST00000665284', 'ENST00000633821', 'ENST00000659315', 'ENST00000668086', 'ENST00000670434'], 'LINC02782': ['ENST00000443270'], 'PLCH2': ['ENST00000609981', 'ENST00000449969', 'ENST00000419816', 'ENST00000343889', 'ENST00000278878', 'ENST00000473964', 'ENST00000462379', 'ENST00000378486'], 'SPSB1': ['ENST00000328089', 'ENST00000450402', 'ENST00000357898', 'ENST00000377399'], 'SLC2A5': ['ENST00000377424', 'ENST00000487492', 'ENST00000377414', 'ENST00000484798', 'ENST00000474145', 'ENST00000479813', 'ENST00000486632', 'ENST00000487835', 'ENST00000464985', 'ENST00000473209'], 'LINC02781': ['ENST00000641403'], 'MTCYBP45': ['ENST00000435243'], 'PLEKHM2': ['ENST00000375799', 'EN
', 'MT1XP1', 'ARHGEF19-AS1', 'DYNLL1P3', 'SZRD1', 'PDIK1L', 'NECAP2', 'IGSF21-AS1', 'PPIAP34', 'LAPTM5', 'SLC30A2', 'PHACTR4', 'IFITM3P7', 'CNKSR1', 'FAM110D', 'MED18', 'EEF1A1P46', 'MMEL1-AS1', 'LINC01648', 'SLC9A1', 'LDLRAP1', 'ATP5IF1', 'SDC3', 'PAFAH2', 'DNAJC8', 'SESN2', 'SERINC2', 'AJAP1', 'PTAFR', 'NKAIN1', 'SNRNP40', 'SLC25A33', 'GJB3', 'LINC01756', 'DNAJC16', 'EYA3', 'ZNF593', 'FABP3', 'EPHA2', 'LINC02780', 'ARHGEF19', 'KAZN-AS1', 'KAZN', 'CHCHD2P6', 'TNFRSF1B', 'TMEM51-AS2', 'LINC01226', 'UBE4B', 'TMEM51-AS1', 'PLA2G5', 'PTPRU', 'ZMYM6', 'FTLP18', 'GJB5', 'AGO4', 'CDCA8', 'CPLANE2', 'ZBTB8B', 'LINC02810', 'FTH1P1', 'PAX7', 'EXTL1', 'CASZ1', 'AGMAT', 'DNALI1', 'RRAGC', 'SPCS2P4', 'GRIK3', 'PLA2G2D', 'YRDC', 'HNRNPFP1', 'CD24P1', 'GUCA2B', 'RCC2', 'HSPA5P1', 'PSMB2', 'CASP9', 'DDI2', 'UQCRH', 'MIR3659HG', 'RPS29P6', 'SELENOWP1', 'GPR199P', 'THRAP3', 'PADI6', 'PADI4', 'C1orf122', 'LINC01654', 'EPHA10', 'FHL3', 'RHBDL2', 'INPP5B', 'FAM183A', 'ZMYM4', 'UTP11', 'ACTN4P2', 'C1orf216', 'SHMT1P1', 'ACTL8', 'PHB1P12', 'RLF', 'CLSPN', 'GNL2', 'GJA4', 'TUBAP8', 'LINC02812', 'FCF1P6', 'MORN1', 'TUBBP10', 'TTC22', 'RPL6P1', 'TIE1', 'MYCBP', 'DLGAP3', 'GOT2P1', 'TMA16P2', 'RIMS3', 'ECHDC2', 'RAB3B', 'SMIM12', 'MRPS6P2', 'TMEM61', 'CYP4A26P', 'LINC02808', 'LINC02778', 'LINC01343', 'ERI3', 'CZIB', 'FAM151A', 'PODN', 'OSBPL9', 'PHB1P3', 'C1orf210', 'PARS2', 'ZYG11A', 'ZYG11B', 'LINC01755', 'CZIB-DT', 'ST3GAL3-AS1', 'L1TD1', 'TXNDC12', 'TXNDC12-AS1', 'SF3A3', 'FGGY-DT', 'DOCK7-DT', 'LAMTOR5P1', 'MTCO2P34', 'LINC01685', 'PIGQP1', 'TTC4', 'KLF17', 'PLPP3', 'RSPO1', 'SNIP1', 'RPS13P2', 'RPL23AP85', 'CPT2', 'FOXJ3', 'TUT4', 'GTF2F2P2', 'KLF18', 'RPS15AP7', 'GAPDHP51', 'PATJ-DT', 'LINC02791', 'CYP4A43P', 'MAGOH', 'DEPDC1-AS1', 'LINC01707', 'DLEU2L', 'CDKN2C', 'LRP8-DT', 'ELOCP18', 'C1orf87', 'ZSWIM5', 'OMA1', 'SLC35D1', 'HIGD1AP11', 'LRP8', 'TCEANC2', 'KTI12', 'LRRC42', 'PIGPP2', 'GDI2P2', 'LINC01360', 'LINC02567', 'KANK4', 'USP1', 'ERI3-IT1', 'RNFT1P2', 'AK5', 'ADH5P2', 'TXNP2', 'GIPC2', 'RPE65', 'ANGPTL3', 'KRT8P21', 'DNAJC6', 'AK4', 'LEPROT', 'RPL31P12', 'LINC02796', 'NDUFS5P3', 'CACHD1', 'EFCAB7', 'LINC02238', 'MCOLN2', 'ST6GALNAC5', 'ATG4C', 'LINC02797', 'COX6CP13', 'TXN2P1', 'PDE4B-AS1', 'ASB17', 'ADGRL4', 'GJA9', 'MTF1', 'TTLL7', 'KDM4A', 'TTLL7-IT1', 'NEGR1-IT1', 'CAPNS1P1', 'LINC02777', 'LDC1P', 'ZNHIT6', 'MGC27382', 'MROH7', 'LINC01763', 'PTGFR', 'LINC02801', 'EEF1GP7', 'LMO4', 'PRPF38A', 'PIGK', 'HNRNPA3P12', 'ST6GALNAC3', 'PGBD4P8', 'MTND2P30', 'RPL7P10', 'PKN2-AS1', 'LINC02792', 'GUCA2A', 'SLC25A6P3', 'PSAT1P3', 'DOCK7', 'NEGR1', 'RPL36AP10', 'LINC01712', 'FAAH', 'KYAT3', 'SHISAL2A', 'HMGB1P18', 'DNTTIP2', 'HNRNPA1P64', 'PTPRF', 'DHCR24', 'PHKA1P1', 'COL24A1', 'BSND', 'GPX7', 'SLC44A3', 'ACTG1P21', 'LINC01362', 'PKN2', 'DAB1-AS1', 'MTCO1P21', 'LINC01364', 'MIR4422HG', 'ABCD3', 'MROH7-TTC4', 'ALG14', 'ZZZ3', 'YIPF1', 'HNRNPCP9', 'KATNBL1P2', 'LDLRAD1', 'GJB4', 'TMEM125', 'DMRTA2', 'HIVEP3', 'TM2D1', 'HMGB1P45', 'SCP2', 'FAF1-AS1', 'MTND4P11', 'BCAR3', 'MTCO3P21', 'TBCAP2', 'BARHL2', 'OAZ1P1', 'DMAP1', 'AHCYL1', 'CNN3', 'OOSP1P1', 'VAV3', 'EEF1A1P11', 'LINC01361', 'RPS20P5', 'DPYD', 'TLCD4', 'H3P2', 'POU3F1', 'LRRC8D', 'S1PR1', 'NFU1P2', 'ELAPOR1', 'ARHGAP29', 'ST13P21', 'LINC02790', 'PGM1', 'IGSF21', 'COA7', 'RNPC3-DT', 'DPYD-IT1', 'OLFML3', 'GCLM', 'TGFBR3', 'CNOT7P2', 'VAV3-AS1', 'RPL21P23', 'RPL36AP12', 'ALG14-AS1', 'MTND3P21', 'ELAVL4-AS1', 'SZT2', 'LINC01349', 'PHTF1', 'RRAS2P1', 'RPSAP19', 'BCAS2P2', 'F3', 'FTH1P22', 'WARS2-IT1', 'LINC01739', 'DNAJA1P5', 'VCAM1', 'HSP90B3P', 'HSD3BP2', 'LINC01787', 'SEC63P1', ...
# 3830
# ['"lncRNA";', '"transcribed_processed_pseudogene";', '"processed_pseudogene";', '"TEC";', '"unprocessed_pseudogene";', '"protein_coding";', '"miRNA";', '"scaRNA";', '"snoRNA";', '"pseudogene";', '"misc_RNA";', '"snRNA";', '"transcribed_unprocessed_pseudogene";', '"transcribed_unitary_pseudogene";']
